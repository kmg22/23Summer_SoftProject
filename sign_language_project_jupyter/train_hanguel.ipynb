# %%
import numpy as np
import os

os.environ['CUDA_VISIBLE_DEVICES'] = '1'
os.environ['TF_FORCE_GPU_ALLOW_GROWTH'] = 'true'

actions = ['ㄱ','ㄴ','ㄷ','ㄹ','ㅁ','ㅂ','ㅅ','ㅇ','ㅈ','ㅊ','ㅋ','ㅌ','ㅍ','ㅎ','ㅏ','ㅑ','ㅓ','ㅕ','ㅗ','ㅛ','ㅜ','ㅠ','ㅡ','ㅣ','ㅐ','ㅒ','ㅔ','ㅖ','ㅚ','ㅟ','ㅢ','space','backspace','clear','sum']

data = np.concatenate([
    np.load('C:/Users/kelly/IdeaProjects/Project mid/dataset/seq_ㄱ_1689662558.npy'),
    np.load('C:/Users/kelly/IdeaProjects/Project mid/dataset/seq_ㄴ_1689662558.npy'),
    np.load('C:/Users/kelly/IdeaProjects/Project mid/dataset/seq_ㄷ_1689662558.npy'),
    np.load('C:/Users/kelly/IdeaProjects/Project mid/dataset/seq_ㄹ_1689662558.npy'),
    np.load('C:/Users/kelly/IdeaProjects/Project mid/dataset/seq_ㅁ_1689662558.npy'),
    np.load('C:/Users/kelly/IdeaProjects/Project mid/dataset/seq_ㅂ_1689662558.npy'),
    np.load('C:/Users/kelly/IdeaProjects/Project mid/dataset/seq_ㅅ_1689662558.npy'),
    np.load('C:/Users/kelly/IdeaProjects/Project mid/dataset/seq_ㅇ_1689662558.npy'),
    np.load('C:/Users/kelly/IdeaProjects/Project mid/dataset/seq_ㅈ_1689662558.npy'),
    np.load('C:/Users/kelly/IdeaProjects/Project mid/dataset/seq_ㅊ_1689662558.npy'),
    np.load('C:/Users/kelly/IdeaProjects/Project mid/dataset/seq_ㅋ_1689662558.npy'),
    np.load('C:/Users/kelly/IdeaProjects/Project mid/dataset/seq_ㅌ_1689662558.npy'),
    np.load('C:/Users/kelly/IdeaProjects/Project mid/dataset/seq_ㅍ_1689662558.npy'),
    np.load('C:/Users/kelly/IdeaProjects/Project mid/dataset/seq_ㅎ_1689662558.npy'),
    np.load('C:/Users/kelly/IdeaProjects/Project mid/dataset/seq_ㅏ_1689662558.npy'),
    np.load('C:/Users/kelly/IdeaProjects/Project mid/dataset/seq_ㅑ_1689662558.npy'),
    np.load('C:/Users/kelly/IdeaProjects/Project mid/dataset/seq_ㅓ_1689662558.npy'),
    np.load('C:/Users/kelly/IdeaProjects/Project mid/dataset/seq_ㅕ_1689662558.npy'),
    np.load('C:/Users/kelly/IdeaProjects/Project mid/dataset/seq_ㅗ_1689662558.npy'),
    np.load('C:/Users/kelly/IdeaProjects/Project mid/dataset/seq_ㅛ_1689662558.npy'),
    np.load('C:/Users/kelly/IdeaProjects/Project mid/dataset/seq_ㅜ_1689662558.npy'),
    np.load('C:/Users/kelly/IdeaProjects/Project mid/dataset/seq_ㅠ_1689662558.npy'),
    np.load('C:/Users/kelly/IdeaProjects/Project mid/dataset/seq_ㅡ_1689662558.npy'),
    np.load('C:/Users/kelly/IdeaProjects/Project mid/dataset/seq_ㅣ_1689662558.npy'),
    np.load('C:/Users/kelly/IdeaProjects/Project mid/dataset/seq_ㅐ_1689662558.npy'),
    np.load('C:/Users/kelly/IdeaProjects/Project mid/dataset/seq_ㅒ_1689662558.npy'),
    np.load('C:/Users/kelly/IdeaProjects/Project mid/dataset/seq_ㅔ_1689662558.npy'),
    np.load('C:/Users/kelly/IdeaProjects/Project mid/dataset/seq_ㅖ_1689662558.npy'),
    np.load('C:/Users/kelly/IdeaProjects/Project mid/dataset/seq_ㅚ_1689662558.npy'),
    np.load('C:/Users/kelly/IdeaProjects/Project mid/dataset/seq_ㅟ_1689662558.npy'),
    np.load('C:/Users/kelly/IdeaProjects/Project mid/dataset/seq_ㅢ_1689662558.npy'),
    np.load("C:/Users/kelly/IdeaProjects/Project mid/dataset/seq_space_1689662558.npy"),
    np.load("C:/Users/kelly/IdeaProjects/Project mid/dataset/seq_backspace_1689662558.npy"),
   np.load("C:/Users/kelly/IdeaProjects/Project mid/dataset/seq_clear_1689662558.npy"),
    np.load("C:/Users/kelly/IdeaProjects/Project mid/dataset/seq_sum_1689662558.npy")
], axis=0)

data.shape

################################################

x_data = data[:, :, :-1]
labels = data[:, 0, -1]

print(x_data.shape)
print(labels.shape)

################################################

from tensorflow.keras.utils import to_categorical

y_data = to_categorical(labels, num_classes=len(actions))
y_data.shape

################################################

from sklearn.model_selection import train_test_split

x_data = x_data.astype(np.float32)
y_data = y_data.astype(np.float32)

x_train, x_val, y_train, y_val = train_test_split(x_data, y_data, test_size=0.1, random_state=2021)

print(x_train.shape, y_train.shape)
print(x_val.shape, y_val.shape)

################################################

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense

model = Sequential([
    LSTM(32, activation='relu', input_shape=x_train.shape[1:3]),
    Dense(1024, activation='relu'),
    Dense(len(actions), activation='softmax')
])

model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['acc'])
model.summary()

################################################

from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau

history = model.fit(
    x_train,
    y_train,
    validation_data=(x_val, y_val),
    epochs=200,
    callbacks=[
        ModelCheckpoint('models/models.h5', monitor='val_acc', verbose=1, save_best_only=True, mode='auto'),
        ReduceLROnPlateau(monitor='val_acc', factor=0.5, patience=50, verbose=1, mode='auto')
    ]
)
# Out:
# (14699, 30, 75)
# (14699,)
# (13229, 30, 75) (13229, 35)
# (1470, 30, 75) (1470, 35)
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  lstm_1 (LSTM)               (None, 32)                13824
#
#  dense_2 (Dense)             (None, 1024)              33792
#
#  dense_3 (Dense)             (None, 35)                35875
#
# ...
# Total params: 83,491
# Trainable params: 83,491
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/210
# 414/414 [==============================] - ETA: 0s - loss: 5.4008 - acc: 0.5233
# Epoch 1: val_acc improved from -inf to 0.67823, saving model to models\models.h5
# 414/414 [==============================] - 17s 31ms/step - loss: 5.4008 - acc: 0.5233 - val_loss: 1.8963 - val_acc: 0.6782 - lr: 0.0010
# Epoch 2/210
# 414/414 [==============================] - ETA: 0s - loss: 2.0007 - acc: 0.7179
# ...
